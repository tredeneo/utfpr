# %%
import pandas
csv = pandas.read_parquet("./teste.parquet")

# %%
csv.head(5)
# Out:
#   date_posted  funny  helpful  hour_played  is_early_access_review
# 0  2018-12-24     25      588          865                   False  \
# 1  2017-05-28     23      880          391                   False
# 2  2018-01-25      0        0          483                   False
# 3  2015-12-28      1        1          760                   False
# 4  2014-06-10      0        0         1920                   False
#
#   recommendation                                             review     title
# 0    Recommended  So here's a simplified list of what you'll fin...  Terraria  \
# 1    Recommended  Honestly I don't know why Terraria has so many...  Terraria
# 2    Recommended  Great game ive spent many hours lost in this f...  Terraria
# 3    Recommended  This game is clearly my favorite game it is am...  Terraria
# 4    Recommended                          Not very replayable. 9/10  Terraria
#
#   lang                                        no_contract
# ...
