# %% [markdown]
# ## Exercício sobre pytorch

# %% [markdown]
# Utilize o dataset 'datasetCarros.csv'.<br>
# Usando Pytorch, construa uma rede neural para prever a feature 'PrecoVenda'.<br>
#
# Use uma rede neural feed forward com duas camadas escondidas, com 20 neurônios cada.<br>
# Use o critério de perda MSELoss, otimizador Adam e learning rate = 0.001. Considere 1000 épocas.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from torch import nn
import torch
import numpy as np

class Feedforward(torch.nn.Module):
    
        def __init__(self, input_size, hidden_size):
            super(Feedforward, self).__init__()
            
            self.input_size = input_size
            self.hidden_size  = hidden_size
            self.fc1 = torch.nn.Linear(self.input_size, self.hidden_size)
            self.fc2 = torch.nn.Linear(self.hidden_size, self.hidden_size)
            self.fc3 = torch.nn.Linear(self.hidden_size, 1)
            
            self.relu = torch.nn.ReLU()
            
            
        def forward(self, x):
            output = self.fc1(x)
            output = self.relu(output)
            
            output = self.fc2(output)
            output = self.relu(output)
            
            output = self.fc3(output)

            return output

device = "cuda" if torch.cuda.is_available() else "cpu"

dfCarros = pd.read_csv('datasetCarros.csv')

dfCarros.replace({'TipoCombustivel':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
dfCarros.replace({'Trasmissao':{'Manual':0,'Automatic':1}},inplace=True)


y= dfCarros['PrecoVenda']
X = dfCarros.drop(['Nome','PrecoVenda'],axis=1)


y_tensor = torch.tensor(y)
X_tensor = torch.tensor(X.to_numpy())
print(y_tensor.shape)
print(X_tensor.shape)

X_treino, X_teste, y_treino, y_teste = train_test_split(X_tensor, y_tensor, test_size = 0.10, random_state=5)

print(X_treino.shape)
print(y_treino.shape)

X_treino = X_treino.float().to(device)
y_treino = y_treino.float().to(device)

X_teste = X_teste.float().to(device)
y_teste = y_teste.float().to(device)


model = Feedforward(6, 20).to(device)
print(model)
criterion = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


model.eval()
y_pred = model(X_teste)
antes_treino = criterion(y_pred, y_teste) 
print('Teste - perda antes do treinamento' , antes_treino.item())

model.train()
epoch = 100

for epoch in range(epoch):
    optimizer.zero_grad()
    
    # Passe Forward
    y_pred = model(X_treino)
    
    # Computa a perda
    loss = criterion(y_pred, y_treino)
    
    print('Epoch {}: perda treino: {}'.format(epoch, loss.item()))
    
    # Passe de Backward
    loss.backward()
    optimizer.step()

    
model.eval()
y_pred = model(X_teste)
after_train = criterion(y_pred, y_teste) 
print('Teste - perda depois do treinamento' , after_train.item())
# Out:
# torch.Size([301])
# torch.Size([301, 6])
# torch.Size([270, 6])
# torch.Size([270])
# Feedforward(
#   (fc1): Linear(in_features=6, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=20, bias=True)
#   (fc3): Linear(in_features=20, out_features=1, bias=True)
#   (relu): ReLU()
# )
# Teste - perda antes do treinamento 1279193.125
# Epoch 0: perda treino: 975009.8125
# Epoch 1: perda treino: 756245.125
# Epoch 2: perda treino: 564338.25
# Epoch 3: perda treino: 402281.8125
# Epoch 4: perda treino: 269969.9375
# Epoch 5: perda treino: 166550.96875
# Epoch 6: perda treino: 90458.8125
# Epoch 7: perda treino: 39450.87890625
# Epoch 8: perda treino: 10600.17578125
# Epoch 9: perda treino: 285.327880859375
# Epoch 10: perda treino: 4256.25732421875
# Epoch 11: perda treino: 17818.15234375
# Epoch 12: perda treino: 36189.53125
# Epoch 13: perda treino: 55027.640625
# Epoch 14: perda treino: 70947.203125
# Epoch 15: perda treino: 81811.5859375
# Epoch 16: perda treino: 86717.2890625
# Epoch 17: perda treino: 85783.9609375
# Epoch 18: perda treino: 79854.1640625
# Epoch 19: perda treino: 70197.140625
# Epoch 20: perda treino: 58253.046875
# Epoch 21: perda treino: 45435.359375
# Epoch 22: perda treino: 32990.578125
# Epoch 23: perda treino: 21906.9453125
# Epoch 24: perda treino: 12867.7607421875
# Epoch 25: perda treino: 6239.97900390625
# Epoch 26: perda treino: 2093.47900390625
# Epoch 27: perda treino: 243.81887817382812
# Epoch 28: perda treino: 312.2672119140625
# Epoch 29: perda treino: 1795.26171875
# Epoch 30: perda treino: 4136.8701171875
# Epoch 31: perda treino: 6795.255859375
# Epoch 32: perda treino: 9298.30078125
# Epoch 33: perda treino: 11282.73046875
# Epoch 34: perda treino: 12515.7451171875
# Epoch 35: perda treino: 12898.611328125
# Epoch 36: perda treino: 12454.982421875
# Epoch 37: perda treino: 11307.34765625
# Epoch 38: perda treino: 9646.3154296875
# Epoch 39: perda treino: 7697.2705078125
# Epoch 40: perda treino: 5688.25634765625
# Epoch 41: perda treino: 3822.6494140625
# Epoch 42: perda treino: 2258.49072265625
# Epoch 43: perda treino: 1096.1968994140625
# Epoch 44: perda treino: 374.7349548339844
# Epoch 45: perda treino: 75.6680908203125
# Epoch 46: perda treino: 133.53672790527344
# Epoch 47: perda treino: 450.7774353027344
# Epoch 48: perda treino: 914.6713256835938
# Epoch 49: perda treino: 1414.02734375
# Epoch 50: perda treino: 1853.344970703125
# Epoch 51: perda treino: 2162.86572265625
# Epoch 52: perda treino: 2303.854248046875
# Epoch 53: perda treino: 2268.819580078125
# Epoch 54: perda treino: 2077.44873046875
# Epoch 55: perda treino: 1769.4002685546875
# Epoch 56: perda treino: 1395.4368896484375
# Epoch 57: perda treino: 1008.3380126953125
# Epoch 58: perda treino: 655.0045166015625
# Epoch 59: perda treino: 370.6410217285156
# Epoch 60: perda treino: 175.50595092773438
# Epoch 61: perda treino: 74.34732055664062
# Epoch 62: perda treino: 58.16835403442383
# Epoch 63: perda treino: 107.68981170654297
# Epoch 64: perda treino: 197.82452392578125
# Epoch 65: perda treino: 302.26397705078125
# Epoch 66: perda treino: 397.5589294433594
# Epoch 67: perda treino: 466.1148986816406
# Epoch 68: perda treino: 497.8399353027344
# Epoch 69: perda treino: 490.4158020019531
# Epoch 70: perda treino: 448.34039306640625
# Epoch 71: perda treino: 381.0799865722656
# Epoch 72: perda treino: 300.748779296875
# Epoch 73: perda treino: 219.7593994140625
# Epoch 74: perda treino: 148.76632690429688
# Epoch 75: perda treino: 95.25221252441406
# Epoch 76: perda treino: 62.819915771484375
# Epoch 77: perda treino: 51.21934127807617
# Epoch 78: perda treino: 57.00239181518555
# Epoch 79: perda treino: 74.60256958007812
# Epoch 80: perda treino: 97.58855438232422
# Epoch 81: perda treino: 119.85736846923828
# Epoch 82: perda treino: 136.59298706054688
# Epoch 83: perda treino: 144.8585662841797
# Epoch 84: perda treino: 143.7670440673828
# Epoch 85: perda treino: 134.27877807617188
# Epoch 86: perda treino: 118.72732543945312
# Epoch 87: perda treino: 100.16584777832031
# Epoch 88: perda treino: 81.71256256103516
# Epoch 89: perda treino: 65.98959350585938
# Epoch 90: perda treino: 54.733985900878906
# Epoch 91: perda treino: 48.63629913330078
# Epoch 92: perda treino: 47.39242172241211
# Epoch 93: perda treino: 49.91966247558594
# Epoch 94: perda treino: 54.68108367919922
# Epoch 95: perda treino: 60.03596115112305
# Epoch 96: perda treino: 64.55412292480469
# Epoch 97: perda treino: 67.23675537109375
# Epoch 98: perda treino: 67.62593841552734
# Epoch 99: perda treino: 65.79376983642578
# Teste - perda depois do treinamento 46.25017547607422
# /home/thiago/anaconda3/lib/python3.8/site-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([31])) that is different to the input size (torch.Size([31, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /home/thiago/anaconda3/lib/python3.8/site-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([270])) that is different to the input size (torch.Size([270, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
